# %% [markdown]
# <a href="https://colab.research.google.com/github/ChumaXe/ML-For-Beginners/blob/main/JTF_sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/nigerian_presidential_election_2023_tweets.csv')
df
# Out:
# <ipython-input-10-ead98df78699>:1: DtypeWarning: Columns (0,5,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/nigerian_presidential_election_2023_tweets.csv')
#                           id           user_name       user_location  \
# 0        1617619263392743424       Fabulous Faga  Abakaliki, Nigeria
# 1        1617648566977302534  Patriotic Nigerian      Lagos, Nigeria
# 2        1617657018873171969             Promise                 NaN
# 3        1617584206317752321              KemKem      Lagos, Nigeria
# 4        1617619489184690178            Mo'6icky                 NaN
# ...                      ...                 ...                 ...
# 74559  1629802540056342528.0      Atiku Abubakar                 NaN
# 74560  1629460175311519744.0      Atiku Abubakar                 NaN
# 74561  1629460171301740544.0      Atiku Abubakar                 NaN
# ...

# %%
df['text']
# Out:
# 0        #OBI and #wife storm kastina state today.\n\nS...
# 1        If they can’t point to you one project , inves...
# 2        @atiku God with his infinite mercy will never ...
# 3        Governor @RotimiAkeredolu takes Asiwaju Bola A...
# 4            @atiku Salutation is not Love. #Obi is coming
#                                ...
# 74559    I received with great sadness reports of the r...
# 74560    My deepest condolences to his family and the F...
# 74561    Hon Sunday Zaka truly embodied the Recovery sp...
# 74562    I just exercised my right to vote. Let’s all d...
# 74563    I arrived in Yola not long ago, preparatory to...
# Name: text, Length: 74564, dtype: object

# %% [markdown]
# Clean this Data for our class on Tuesday

# %%
df
# Out:
#                           id           user_name       user_location  \
# 0        1617619263392743424       Fabulous Faga  Abakaliki, Nigeria
# 1        1617648566977302534  Patriotic Nigerian      Lagos, Nigeria
# 2        1617657018873171969             Promise                 NaN
# 3        1617584206317752321              KemKem      Lagos, Nigeria
# 4        1617619489184690178            Mo'6icky                 NaN
# ...                      ...                 ...                 ...
# 74559  1629802540056342528.0      Atiku Abubakar                 NaN
# 74560  1629460175311519744.0      Atiku Abubakar                 NaN
# 74561  1629460171301740544.0      Atiku Abubakar                 NaN
# 74562  1629409042543124480.0      Atiku Abubakar                 NaN
# 74563  1628854814556790784.0      Atiku Abubakar                 NaN
#
#                                         user_description  \
# 0      🌹A Social media influencer\n💃A scientist by pr...
# ...
